# %%
import pandas as pd

# Replace 'your_file_name.csv' with the exact filename of your dataset
file_path = '2024-child-and-adult-health-care-quality-measures.csv' 

# Load the file
df = pd.read_csv(file_path)

# Display total rows/columns and the first 5 lines
print(f"Loaded {df.shape[0]} rows and {df.shape[1]} columns.\n")
print(df.columns.tolist())
df.head()
# Out:
# Loaded 11100 rows and 20 columns.
#
# ['State', 'Domain', 'Reporting Program', 'Measure Name', 'Measure Abbreviation', 'Measure Type', 'Rate Definition', 'Core Set Year', 'Population', 'Methodology', 'State Rate', 'Number of States Reporting', 'Mean', 'Median', 'Bottom Quartile', 'Top Quartile', 'Notes', 'Source', 'State-Specific Comments', 'Rate Used in Calculating State Mean and Median']
#      State                  Domain Reporting Program  \
# 0  Alabama  Behavioral Health Care    Child Core Set
# 1  Alabama  Behavioral Health Care    Child Core Set
# 2  Alabama  Behavioral Health Care    Child Core Set
# 3  Alabama  Behavioral Health Care    Child Core Set
# 4  Alabama  Behavioral Health Care    Child Core Set
#
#                                         Measure Name Measure Abbreviation  \
# 0  Follow-Up After Emergency Department Visit for...               FUM-CH
# 1  Follow-Up After Emergency Department Visit for...               FUM-CH
# ...

# %%
# Summary of data types and non-null value counts
df.info()

# Count total missing values per column
print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11100 entries, 0 to 11099
# Data columns (total 20 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   State                                           11100 non-null  str
#  1   Domain                                          11100 non-null  str
#  2   Reporting Program                               11100 non-null  str
#  3   Measure Name                                    11100 non-null  str
#  4   Measure Abbreviation                            11100 non-null  str
#  5   Measure Type                                    11100 non-null  str
#  6   Rate Definition                                 11100 non-null  str
#  7   Core Set Year                                   11100 non-null  int64
#  8   Population                                      11100 non-null  str
# ...
